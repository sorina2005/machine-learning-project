# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, precision_recall_fscore_support

SEED = 42
TARGET_COLUMN = 'Category'
TRAIN_TEST_RATIO = 0.2

np.random.seed(SEED)

# %%
df = pd.read_csv('HepatitisCdata.csv')
df = df.drop(columns=['Unnamed: 0'])

X = df.drop(columns=[TARGET_COLUMN])
y = df[TARGET_COLUMN]

print(f"Dimensiunile datasetului: {df.shape[0]} randuri si {df.shape[1]} coloane")
print(f"Tipurile de variabile:\n{df.dtypes}")
# Out:
# Dimensiunile datasetului: 615 randuri si 13 coloane
# Tipurile de variabile:
# Category     object
# Age           int64
# Sex          object
# ALB         float64
# ALP         float64
# ALT         float64
# AST         float64
# BIL         float64
# CHE         float64
# CHOL        float64
# CREA        float64
# GGT         float64
# PROT        float64
# dtype: object

# %%
class_distribution = y.value_counts()
class_percentage = y.value_counts(normalize=True) * 100

dist_table = pd.DataFrame({
    'Count': class_distribution,
    'Percentage (%)': class_percentage
})

print(dist_table)
# Out:
#                         Count  Percentage (%)
# Category
# 0=Blood Donor             533       86.666667
# 3=Cirrhosis                30        4.878049
# 1=Hepatitis                24        3.902439
# 2=Fibrosis                 21        3.414634
# 0s=suspect Blood Donor      7        1.138211

# %%
missing_values = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100

missing_report = pd.DataFrame({
    'Missing Count': missing_values,
    'Percentage (%)': missing_percent
})

print(missing_report[missing_report['Missing Count'] > 0])
# Out:
#       Missing Count  Percentage (%)
# ALB               1        0.162602
# ALP              18        2.926829
# ALT               1        0.162602
# CHOL             10        1.626016
# PROT              1        0.162602

# %%
def load_data(path):
    df = pd.read_csv(path)
    if 'Unnamed: 0' in df.columns:
        df = df.drop(columns=['Unnamed: 0'])
    X = df.drop(columns=['Category'])
    y = df['Category']
    X['Sex'] = X['Sex'].map({'m': 1, 'f': 0})
    le = LabelEncoder()
    y_encoded = le.fit_transform(y)
    return X, y_encoded, le

def preprocess_split(X, y, test_size, seed):
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=seed, stratify=y
    )
    imputer = SimpleImputer(strategy='median')
    scaler = RobustScaler()
    
    X_train_proc = imputer.fit_transform(X_train)
    X_train_proc = scaler.fit_transform(X_train_proc)
    
    X_test_proc = imputer.transform(X_test)
    X_test_proc = scaler.transform(X_test_proc)
    
    return X_train_proc, X_test_proc, y_train, y_test

# %%
def plot_results(y_true, y_pred, y_prob, labels):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=labels, yticklabels=labels)
    plt.title('Matrice de Confuzie')
    plt.show()

    plt.figure(figsize=(8, 6))
    for i in range(len(labels)):
        fpr, tpr, _ = roc_curve(y_true == i, y_prob[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'{labels[i]} (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.title('Curba ROC (One-vs-Rest)')
    plt.legend()
    plt.show()

# %%
def run_experiment(model, X, y, test_size, seed, labels):
    X_train, X_test, y_train, y_test = preprocess_split(X, y, test_size, seed)
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)
    print(classification_report(y_test, y_pred, target_names=labels, zero_division=0))
    plot_results(y_test, y_pred, y_prob, labels)
    
    return model

# %%
seeds = [42, 10, 100]
proportii = [0.2, 0.3, 0.4]

X, y_encoded, le = load_data('HepatitisCdata.csv')

for s in seeds:
    for p in proportii:
        print(f"\nExperiment: Seed={s}, Test_Size={p}")
        model = KNeighborsClassifier()
        run_experiment(model, X, y_encoded, p, s, le.classes_)
# Out:
# Experiment: Seed=42, Test_Size=0.2
#                         precision    recall  f1-score   support
#
#          0=Blood Donor       0.96      1.00      0.98       107
# 0s=suspect Blood Donor       0.00      0.00      0.00         1
#            1=Hepatitis       0.67      0.40      0.50         5
#             2=Fibrosis       0.67      0.50      0.57         4
#            3=Cirrhosis       1.00      0.67      0.80         6
#
#               accuracy                           0.93       123
#              macro avg       0.66      0.51      0.57       123
#           weighted avg       0.93      0.93      0.93       123
# Experiment: Seed=42, Test_Size=0.3
#                         precision    recall  f1-score   support
#
#          0=Blood Donor       0.96      1.00      0.98       161
# 0s=suspect Blood Donor       0.00      0.00      0.00         2
#            1=Hepatitis       0.60      0.43      0.50         7
#             2=Fibrosis       0.33      0.33      0.33         6
#            3=Cirrhosis       0.83      0.56      0.67         9
#
#               accuracy                           0.92       185
#              macro avg       0.55      0.46      0.50       185
#           weighted avg       0.91      0.92      0.92       185
# Experiment: Seed=42, Test_Size=0.4
#                         precision    recall  f1-score   support
#
#          0=Blood Donor       0.94      1.00      0.97       213
# 0s=suspect Blood Donor       0.00      0.00      0.00         3
#            1=Hepatitis       0.50      0.30      0.38        10
#             2=Fibrosis       0.14      0.12      0.13         8
#            3=Cirrhosis       0.88      0.58      0.70        12
#
#               accuracy                           0.91       246
#              macro avg       0.49      0.40      0.44       246
#           weighted avg       0.88      0.91      0.89       246
# Experiment: Seed=10, Test_Size=0.2
#                         precision    recall  f1-score   support
#
#          0=Blood Donor       0.94      1.00      0.97       107
# 0s=suspect Blood Donor       0.00      0.00      0.00         1
#            1=Hepatitis       0.50      0.20      0.29         5
#             2=Fibrosis       0.50      0.25      0.33         4
#            3=Cirrhosis       1.00      0.83      0.91         6
#
#               accuracy                           0.93       123
#              macro avg       0.59      0.46      0.50       123
#           weighted avg       0.90      0.93      0.91       123
# Experiment: Seed=10, Test_Size=0.3
#                         precision    recall  f1-score   support
#
#          0=Blood Donor       0.95      1.00      0.97       161
# 0s=suspect Blood Donor       0.00      0.00      0.00         2
#            1=Hepatitis       0.00      0.00      0.00         7
#             2=Fibrosis       0.38      0.50      0.43         6
#            3=Cirrhosis       1.00      0.78      0.88         9
#
#               accuracy                           0.92       185
#              macro avg       0.46      0.46      0.46       185
#           weighted avg       0.89      0.92      0.90       185
# Experiment: Seed=10, Test_Size=0.4
#                         precision    recall  f1-score   support
#
#          0=Blood Donor       0.93      1.00      0.96       213
# 0s=suspect Blood Donor       0.00      0.00      0.00         3
#            1=Hepatitis       0.00      0.00      0.00        10
#             2=Fibrosis       0.30      0.38      0.33         8
#            3=Cirrhosis       1.00      0.50      0.67        12
#
#               accuracy                           0.90       246
#              macro avg       0.45      0.38      0.39       246
#           weighted avg       0.86      0.90      0.88       246
# Experiment: Seed=100, Test_Size=0.2
#                         precision    recall  f1-score   support
#
#          0=Blood Donor       0.94      1.00      0.97       107
# 0s=suspect Blood Donor       0.00      0.00      0.00         1
#            1=Hepatitis       0.00      0.00      0.00         5
#             2=Fibrosis       1.00      0.25      0.40         4
#            3=Cirrhosis       1.00      0.33      0.50         6
#
#               accuracy                           0.89       123
#              macro avg       0.59      0.32      0.37       123
#           weighted avg       0.90      0.89      0.88       123
# Experiment: Seed=100, Test_Size=0.3
#                         precision    recall  f1-score   support
#
#          0=Blood Donor       0.95      1.00      0.97       161
# 0s=suspect Blood Donor       0.00      0.00      0.00         2
#            1=Hepatitis       0.17      0.14      0.15         7
#             2=Fibrosis       1.00      0.33      0.50         6
#            3=Cirrhosis       0.86      0.67      0.75         9
#
#               accuracy                           0.92       185
#              macro avg       0.59      0.43      0.48       185
#           weighted avg       0.90      0.92      0.91       185
# Experiment: Seed=100, Test_Size=0.4
#                         precision    recall  f1-score   support
#
#          0=Blood Donor       0.94      1.00      0.97       213
# 0s=suspect Blood Donor       0.00      0.00      0.00         3
#            1=Hepatitis       0.29      0.20      0.24        10
#             2=Fibrosis       0.75      0.38      0.50         8
#            3=Cirrhosis       0.88      0.58      0.70        12
#
#               accuracy                           0.91       246
#              macro avg       0.57      0.43      0.48       246
#           weighted avg       0.89      0.91      0.90       246
